# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#%cd /content/drive/MyDrive/Colab_Notebooks/tavu/Anomaly-Transformer-run/Anomaly-Transformer-main
# %cd /content/drive/MyDrive/TAVE_AIFactory/0415국현/Anomaly-Transformer-run/Anomaly-Transformer-main
# %cd /content/drive/MyDrive/tavu/Anomaly-Transformer-run/Anomaly-Transformer-main
# %cd /content/drive/MyDrive/Colab_Notebooks/tavu/Anomaly-Transformer-run/Anomaly-Transformer-main

# %%
# !ls

# %%
# HP20
#!python main.py --anormly_ratio 3.5 --num_epochs 50  --batch_size 1 --mode train --dataset HP20  --data_path dataset/HP20 --input_c 8   --output_c 8
# !python main.py --anormly_ratio 3.5  --num_epochs 10  --batch_size 1 --mode test  --dataset HP20  --data_path dataset/HP20 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/test_energy_20.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
# 세진 95.5 : 0.003445936178322895
# 국현 95.5 : 0.003046230849251279

#HP20
thre_g = 0.000390333887480665
#thre_s = 0.003445936178322895

threshold_g = [thre_g for _ in range(1107)]
#threshold_s = [thre_s for _ in range(1107)]
plt.scatter(range(1107), test_energy[:])
plt.plot(range((1107)), threshold_g, color = 'r')
#plt.plot(range((1107)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.001])
plt.title('HP20')
plt.show()

# %% [markdown]
# type3

# %%
# HP50
# !python main.py --anormly_ratio 3.5 --num_epochs 50  --batch_size 1 --mode train --dataset HP50  --data_path dataset/HP50 --input_c 8   --output_c 8
# !python main.py --anormly_ratio 2.7  --num_epochs 10  --batch_size 1 --mode test  --dataset HP50  --data_path dataset/HP50 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/test_energy_50.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
# 세진 95.5 : 0.003445936178322895
# 국현 95.5 : 0.003046230849251279

#HP50
thre_g = 0.001197849221993239
#thre_s = 0.003445936178322895

threshold_g = [thre_g for _ in range(918)]
#threshold_s = [thre_s for _ in range(918)]
plt.scatter(range(918), test_energy[:])
plt.plot(range((918)), threshold_g, color = 'r')
#plt.plot(range((918)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.001])
plt.title('HP50')
plt.show()

# %% [markdown]
# HP30

# %%
# HP30
#!python main.py --anormly_ratio 3.5 --num_epochs 50  --batch_size 1 --mode train --dataset HP30  --data_path dataset/HP30 --input_c 8   --output_c 8
# !python main.py --anormly_ratio 5.1  --num_epochs 10  --batch_size 1 --mode test  --dataset HP30  --data_path dataset/HP30 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/test_energy_30.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
# 세진 95.5 : 0.003445936178322895
# 국현 95.5 : 0.003046230849251279

#HP30

thre_g = 0.0009866622156702637
#thre_s = 0.003445936178322895

threshold_g = [thre_g for _ in range(4266)]
#threshold_s = [thre_s for _ in range(4266)]
plt.scatter(range(4266), test_energy[:])
plt.plot(range((4266)), threshold_g, color = 'r')
#plt.plot(range((4266)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.0001])
plt.title('HP30')
plt.show()

# %% [markdown]
# hp10

# %%
# HP10 ratio : 1.6 - best
#!python main.py --anormly_ratio 3.5 --num_epochs 50 --batch_size 1 --mode train --dataset HP10  --data_path dataset/HP10 --input_c 8   --output_c 8
# !python main.py --anormly_ratio 4.25  --num_epochs 10  --batch_size 1 --mode test  --dataset HP10  --data_path dataset/HP10 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/test_energy_10.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
# 세진 95.5 : 0.003445936178322895
# 국현 95.5 : 0.003046230849251279

#HP30
thre_g = 0.0003916938717156881
#thre_g = 0.003233708900864935
# thre_s = 0.003046230849251279

threshold_g = [thre_g for _ in range(1098)]
# threshold_s = [thre_s for _ in range(1098)]
plt.scatter(range(1098), test_energy[:])
plt.plot(range((1098)), threshold_g, color = 'r')
# plt.plot(range((1098)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.001])
plt.title('HP10')
plt.show()

# %% [markdown]
# # 버리기!

# %% [markdown]
# # 여기서부터!

# %%
# TOTAL
# 실행하기 전에 solver.py 135 line 풀어주세요!  -> 근데 나 안함
# !python main.py --anormly_ratio 3.5 --num_epochs 50  --batch_size 16 --mode train --dataset TOTAL  --data_path dataset/TOTAL --input_c 8   --output_c 8
# !python main.py --anormly_ratio 3.53  --num_epochs 10  --batch_size 16 --mode test  --dataset TOTAL  --data_path dataset/TOTAL --input_c 8   --output_c 8  #--pretrained_model None

# %% [markdown]
# # 임시

# %%
# TYPE0
# !python main.py --anormly_ratio 4  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE0  --data_path dataset/TYPE0 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy_1.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [23386.166015625 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.title('TYPE0')
plt.show()

# %%
# TYPE1
# !python main.py --anormly_ratio 5  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.036119346506893635 for _ in range(1107)]
plt.scatter(range(1107), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1107), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %%
# TYPE2
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE2  --data_path dataset/TYPE2 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.01112179674208163 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %%
# TYPE3
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.01112179674208163 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %%
# TYPE4
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.01112179674208163 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %%
# TYPE5
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.01112179674208163 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %%
# TYPE6
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.01112179674208163 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %%
# TYPE7
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
#TYPE0
thre = 0.01112179674208163
#threshold = [thre for _ in range(1296)]
threshold = [0.01112179674208163 for _ in range(1296)]
plt.scatter(range(1296), test_energy[:])
#plt.plot(range(1296), test_energy[:])
plt.plot(range(1296), threshold, color = 'r')
plt.ylim([0,thre+0.01])
plt.title('TYPE0')
plt.show()

# %% [markdown]
# # test_energy_시각화 for ratio 설정

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/test_energy_1.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

# %%
# 세진 95.5 : 0.003445936178322895
# 국현 95.5 : 0.003046230849251279

#TOTAL
'''threshold = [0.0026214777026325464 for _ in range(7389)]
plt.plot(range(7389), test_energy)
plt.plot(range(7389), threshold, color = 'r')
plt.show()'''

#TYPE0
thre_g = 0.0027419305610704887
thre_s = 0.003445936178322895

threshold_g = [thre_g for _ in range(1296)]
threshold_s = [thre_s for _ in range(1296)]
plt.scatter(range(1296), test_energy[:1296])
#plt.plot(range(1296), test_energy[:1296])
plt.plot(range((1296)), threshold_g, color = 'r')
plt.plot(range((1296)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.01])
plt.title('TYPE0')
plt.show()

# %%
#TYPE1
threshold = [thre_g for _ in range(1107)]
plt.scatter(range(1107), test_energy[1296:2403])
plt.plot(range(1107), threshold, color = 'r')
plt.title('TYPE1')
plt.show()

# %%
#TYPE2
thre_g =0.0027419305610704887
#thre_s = 0.003046230849251279
thre_s = 0.003445936178322895
threshold_g = [thre_g for _ in range(1098)]
threshold_s = [thre_s for _ in range(1098)]
plt.scatter(range(1098), test_energy[2403:3501])
plt.plot(range((1098)), threshold_g, color = 'r')
plt.plot(range((1098)), threshold_s, color = 'b')
plt.title('TYPE2')
# plt.ylim([0,thre_g+0.01])
plt.ylim([0.002,0.004])
plt.show()

# %%
#TYPE3
thre_g = 0.0027419305610704887
thre_s = 0.003046230849251279
threshold_g = [thre_g for _ in range((4419-3501))]
threshold_s = [thre_s for _ in range((4419-3501))]
plt.scatter(range((4419-3501)), test_energy[3501:4419])
plt.plot(range((4419-3501)), threshold_g, color = 'r')
plt.plot(range((4419-3501)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.01])
plt.title('TYPE3')
plt.show()

# %%
#TYPE4
thre_g = 0.0027419305610704887
thre_s = 0.003046230849251279
threshold_g = [thre_g for _ in range((5337-4419))]
threshold_s = [thre_s for _ in range((5337-4419))]
plt.plot(range((4419-3501)), threshold_g, color = 'r')
plt.scatter(range((5337-4419)), test_energy[4419:5337])

plt.plot(range((4419-3501)), threshold_s, color = 'b')
plt.ylim([thre_g-0.001,thre_g+0.001])
#plt.ylim([0.0010,0.0002])
plt.title('TYPE4')
plt.show()

# %%
#TYPE5
thre_g = 0.0027419305610704887
thre_s = 0.003445936178322895
threshold_g = [thre_g for _ in range((6084-5337))]
threshold_s = [thre_s for _ in range((6084-5337))]
plt.scatter(range((6084-5337)), test_energy[5337:6084])
plt.plot(range((6084-5337)), threshold_g, color = 'r')
plt.plot(range((6084-5337)), threshold_s, color = 'b')
plt.title('TYPE5')
plt.ylim([0,thre_g+0.01])
plt.show()

# %%
#TYPE6
thre_g = 0.0027419305610704887
thre_s = 0.003445936178322895
threshold_g = [thre_g for _ in range((6831-6084))]
threshold_s = [thre_s for _ in range((6831-6084))]
plt.scatter(range((6831-6084)), test_energy[6084:6831])
plt.plot(range((6831-6084)), threshold_g, color = 'r')
plt.plot(range((6831-6084)), threshold_s, color = 'b')
plt.ylim([0,thre_g+0.01])
plt.title('TYPE6')
plt.show()

# %%
#TYPE7
thre_g = 0.0027419305610704887
thre_s = 0.003445936178322895
threshold_g = [thre_g for _ in range((7389-6831))]
threshold_s = [thre_s for _ in range((7389-6831))]
plt.scatter(range((7389-6831)), test_energy[6831:7389])
plt.plot(range((7389-6831)), threshold_g, color = 'r')
plt.plot(range((7389-6831)), threshold_s, color = 'b')
plt.title('TYPE7')
plt.ylim([0,thre_g+0.01])
plt.show()

# %%
# TYPE0
# !python main.py --anormly_ratio 2  --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %% [markdown]
# # TYPE1

# %%
# TYPE1
# 실행하기 전에 solver.py 135 line 풀어주세요!  -> 근데 나 안함
# win_size 1 batch_size 32
# !python main.py --anormly_ratio 3 --num_epochs 50 --batch_size 32 --mode train --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8
# !python main.py --anormly_ratio 3 --num_epochs 10  --batch_size 32 --mode test  --dataset TYPE1  --data_path dataset/TYPE1 --input_c 8   --output_c 8  #--pretrained_model None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test_energy = pd.read_csv('/content/drive/MyDrive/tavu/raw_dataset/test_energy_1.csv', encoding = 'cp949')
test_energy = np.array(test_energy['0'])

#TYPE1
thre
threshold = [0.03119563963264227 for _ in range(1107)]
plt.scatter(range(1107), test_energy[:])
plt.plot(range(1107), threshold, color = 'r')
plt.title('TYPE1')
plt.show()

# %% [markdown]
# # raw_dataset 폴더에 저장된 type_0_answer.csv를 좀 가공(answer_sample에서 열 복붙)해서 제출하면 끝!!!

# %%
# TYPE1
# !python main.py --anormly_ratio 10 --num_epochs 30   --batch_size 32 --win_size 64 --mode train --dataset TYPE1  --data_path dataset/TYPE1 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 10  --num_epochs 1       --batch_size 32 --win_size 1  --mode test    --dataset TYPE1   --data_path dataset/TYPE1  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_1 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_1))

# %%
# TYPE2
# !python main.py --anormly_ratio 7 --num_epochs 30   --batch_size 32 --win_size 64 --mode train --dataset TYPE2  --data_path dataset/TYPE2 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 7  --num_epochs 10       --batch_size 32 --win_size 1   --mode test    --dataset TYPE2   --data_path dataset/TYPE2  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_2 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_2))

# %%
# TYPE3
# !python main.py --anormly_ratio 7 --num_epochs 30    --batch_size 32 --win_size 64  --mode train --dataset TYPE3  --data_path dataset/TYPE3 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 7  --num_epochs 10       --batch_size 32  --win_size 1   --mode test    --dataset TYPE3   --data_path dataset/TYPE3  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_3 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_3))

# %%
# TYPE4
# !python main.py --anormly_ratio 6 --num_epochs 30    --batch_size 32 --win_size 64  --mode train --dataset TYPE4  --data_path dataset/TYPE4 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 6  --num_epochs 10       --batch_size 32  --win_size 1   --mode test    --dataset TYPE4   --data_path dataset/TYPE4  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_4 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_4))

# %%
# TYPE5
# !python main.py --anormly_ratio 7 --num_epochs 30    --batch_size 32 --win_size 64  --mode train --dataset TYPE5  --data_path dataset/TYPE5 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 7  --num_epochs 10       --batch_size 32 --win_size 1    --mode test    --dataset TYPE5   --data_path dataset/TYPE5  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_5 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_5))

# %%
# TYPE6
# !python main.py --anormly_ratio 7 --num_epochs 30    --batch_size 32 --win_size 64 --mode train --dataset TYPE6  --data_path dataset/TYPE6 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 7  --num_epochs 10       --batch_size 32 --win_size 1    --mode test    --dataset TYPE6   --data_path dataset/TYPE6  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_6 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_6))

# %%
# TYPE7
# !python main.py --anormly_ratio 7 --num_epochs 30    --batch_size 32 --win_size 64 --mode train --dataset TYPE7  --data_path dataset/TYPE7 --input_c 7    --output_c 7
# !python main.py --anormly_ratio 7  --num_epochs 10       --batch_size 32  --win_size 1   --mode test    --dataset TYPE7   --data_path dataset/TYPE7  --input_c 7    --output_c 7  --pretrained_model 20

# %%
import pandas as pd
pred_7 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/type_0_answer.csv', encoding = 'cp949')
print(len(pred_7))

# %%
pred = pd.concat([pred_0, pred_1, pred_2, pred_3, pred_4,pred_5,pred_6,pred_7], axis = 0)

# %%
pred.sample(10)

# %%
print(len(pred))
pred.to_csv('/content/drive/MyDrive/Colab_Notebooks/tavu/raw_dataset/pred.csv')
